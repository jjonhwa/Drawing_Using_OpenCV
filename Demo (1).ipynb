# %%
# !git clone https://github.com/jjonhwa/Drawing_Using_OpenCV
# Out:
# Cloning into 'Drawing_Using_OpenCV'...
# remote: Enumerating objects: 21, done.
# remote: Counting objects: 100% (21/21), done.
# remote: Compressing objects: 100% (19/19), done.
# remote: Total 21 (delta 0), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (21/21), done.

# %%
import cv2

from glob import glob
from google.colab.patches import cv2_imshow

# %cd /content/Drawing_Using_OpenCV
from Draw import go_draw
# Out:
# /content/Drawing_Using_OpenCV

# %%
image_list = glob('/content/Drawing_Using_OpenCV/Demo_image/*.jpg')
image = image_list[1]

# %%
cv2_imshow(cv2.imread(image, cv2.IMREAD_COLOR))
# Out:
# <PIL.Image.Image image mode=RGB size=1655x2340 at 0x7F86004149D0>

# %%
cv2_imshow(go_draw(image))
# Out:
# <PIL.Image.Image image mode=RGB size=1655x2340 at 0x7F860DF87CD0>
